# %%
import cv2
path = 'data/lena.png'
img = cv2.imread(path)
print(img)
# Out:
# [[[125 137 226]
#   [125 137 226]
#   [133 137 223]
#   ...
#   [122 148 230]
#   [110 130 221]
#   [ 90  99 200]]
#
#  [[125 137 226]
#   [125 137 226]
#   [133 137 223]
#   ...
#   [122 148 230]
#   [110 130 221]
#   [ 90  99 200]]
#
#  [[125 137 226]
#   [125 137 226]
#   [133 137 223]
#   ...
#   [122 148 230]
#   [110 130 221]
#   [ 90  99 200]]
#
#  ...
#
#  [[ 60  18  84]
#   [ 60  18  84]
#   [ 58  27  92]
#   ...
#   [ 84  73 173]
#   [ 76  68 172]
#   [ 79  62 177]]
#
#  [[ 57  22  82]
#   [ 57  22  82]
#   [ 62  32  96]
#   ...
#   [ 79  70 179]
#   [ 81  71 181]
#   [ 81  74 185]]
#
#  [[ 57  22  82]
#   [ 57  22  82]
#   [ 62  32  96]
#   ...
#   [ 79  70 179]
#   [ 81  71 181]
#   [ 81  74 185]]]

# %%
print(img[:,:,0])
# Out:
# [[125 125 133 ... 122 110  90]
#  [125 125 133 ... 122 110  90]
#  [125 125 133 ... 122 110  90]
#  ...
#  [ 60  60  58 ...  84  76  79]
#  [ 57  57  62 ...  79  81  81]
#  [ 57  57  62 ...  79  81  81]]

# %%
print(img[:,:,1])
# Out:
# [[[125 137 226]
#   [125 137 226]
#   [133 137 223]
#   ...
#   [122 148 230]
#   [110 130 221]
#   [ 90  99 200]]
#
#  [[125 137 226]
#   [125 137 226]
#   [133 137 223]
#   ...
#   [122 148 230]
#   [110 130 221]
#   [ 90  99 200]]
#
#  [[125 137 226]
#   [125 137 226]
#   [133 137 223]
#   ...
#   [122 148 230]
#   [110 130 221]
#   [ 90  99 200]]
#
#  ...
#
#  [[ 60  18  84]
#   [ 60  18  84]
#   [ 58  27  92]
#   ...
#   [ 84  73 173]
#   [ 76  68 172]
#   [ 79  62 177]]
#
#  [[ 57  22  82]
#   [ 57  22  82]
#   [ 62  32  96]
#   ...
#   [ 79  70 179]
#   [ 81  71 181]
#   [ 81  74 185]]
#
#  [[ 57  22  82]
#   [ 57  22  82]
#   [ 62  32  96]
#   ...
#   [ 79  70 179]
#   [ 81  71 181]
#   [ 81  74 185]]]

# %%
print(img[:,:,2])
# Out:
# [[226 226 223 ... 230 221 200]
#  [226 226 223 ... 230 221 200]
#  [226 226 223 ... 230 221 200]
#  ...
#  [ 84  84  92 ... 173 172 177]
#  [ 82  82  96 ... 179 181 185]
#  [ 82  82  96 ... 179 181 185]]
