# %% [markdown]
# 損失函數是描述模型預測出來的結果和實際的差異的依據
# YOLO損失函數的設計包含物件位置的定位與物件類別辨識
# YOLO損失函數透過超參數設定模型有不同的辨識能力
# Homework:
# 仔細觀察，bbox 寬高計算損失方式和bbox中心計算損失方式有何不同? 為何要有不同的設計?

# %%
'''
Bbox寬高的計算方式：先把寬高開開根號後，再算差異的平方，
why?
因為大的預測框容易產生較大的誤差，
如果損失的設計和中心點相同，
會造成模型大物體辨識的能力較差，
因此透過開根號修正這樣的情形。
開根號的效果如下圖，
'''

# %%
import cv2
import matplotlib.pyplot as plt
img = cv2.imread("data/day34.png")
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))

# %%
'''
上圖代表x和√𝑥 的關係，為一個漸漸平緩的曲線，
大物體寬(/高)的預測誤差，和小物體寬(/高)的預測誤差都為 d 時，
透過開根號，
大物體的寬(/高)的預測誤差量會小於小物體的寬(/高)的預測誤差量，
達到大小物件辨識能力接近的設計。
'''
